# %% [markdown]
# <a href="https://colab.research.google.com/github/VittorioBartolomeoSecondin/DVIS-CAValli_Team/blob/main/prova1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import scipy
from google.colab import drive
import csv

# drive.mount('/content/drive')

# %%
all_files = glob.glob("/content/*.csv")

li = []
sum = 0

for filename in all_files:
    #print(filename)
    df = pd.read_csv(filename) #on_bad_lines='skip')
    sum += df.shape[0]
    if li:
        df = df.reindex(columns=li[0].columns)
    li.append(df)

print(sum)
tree_dataset = pd.concat(li, axis=0, ignore_index=True)
# Out:
# <ipython-input-4-7a71f454e1d8>:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename) #on_bad_lines='skip')
# <ipython-input-4-7a71f454e1d8>:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename) #on_bad_lines='skip')
# <ipython-input-4-7a71f454e1d8>:8: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename) #on_bad_lines='skip')
# 5655510

# %%
tree_dataset.tail()
# Out:
#          city_ID most_recent_observation   common_name       scientific_name  \
# 5655505  5653862                     NaN  Crape myrtle  Lagerstroemia indica
# 5655506  5942032                     NaN  Crape myrtle  Lagerstroemia indica
# 5655507  5942033                     NaN  Crape myrtle  Lagerstroemia indica
# 5655508  5942034                     NaN  Crape myrtle  Lagerstroemia indica
# 5655509  5942035                     NaN  Crape myrtle  Lagerstroemia indica
#
#                      city       state  longitude_coordinate  \
# 5655505  Huntington Beach  California           -118.018076
# 5655506  Huntington Beach  California           -118.018226
# 5655507  Huntington Beach  California           -118.018440
# 5655508  Huntington Beach  California           -118.018057
# 5655509  Huntington Beach  California           -118.017860
#
#          latitude_coordinate location_type         address  ... tree_ID  \
# ...

# %%
quantitative_tree = tree_dataset[['']]
qualitative_tree = tree_dataset[['']]

# %%
print(tree_dataset.shape) # N=5132890, 28 columns expected
# Out:
# (5655510, 28)

# %%
tree_dataset['city'].value_counts()
# Out:
# Los Angeles    720140
# New York       683788
# San Jose       347669
# Denver         284739
# Portland       218602
#                 ...
# Muskego             2
# Heeia               1
# Aiea                1
# Wind Lake           1
# Lutz                1
# Name: city, Length: 147, dtype: int64

# %%
for i in list(tree_dataset.columns.values):
  print(i)
  print(tree_dataset[i].value_counts())
  print("%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%")
# Out:
# city_ID
#                            172
# 10340-155-3001-0095-000    126
# 35778-290-3005-0057-000    125
# 2                           63
# 24875-000-3001-0000-000     48
#                           ...
# 399,037                      1
# 402,431                      1
# 399,380                      1
# 398,937                      1
# 5942035                      1
# Name: city_ID, Length: 2300610, dtype: int64
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# most_recent_observation
# 04/27/2019                127866
# 03/23/2015                 96072
# 01/08/2020                 56425
# 11/15/2017                 45336
# 04/11/2018                 29112
#                            ...
# 2022/05/04 21:14:07+00         1
# 2022/03/22 19:15:02+00         1
# 2022/03/23 16:56:42+00         1
# 2022/05/03 18:05:34+00         1
# 2020/08/28 23:36:08+00         1
# Name: most_recent_observation, Length: 18940, dtype: int64
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# common_name
# ...
