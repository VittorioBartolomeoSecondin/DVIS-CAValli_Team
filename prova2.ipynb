# %% [markdown]
# <a href="https://colab.research.google.com/github/VittorioBartolomeoSecondin/DVIS-CAValli_Team/blob/main/prova2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import scipy
import csv

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
all_files = glob.glob("/content/drive/MyDrive/tree_dataset/*.csv")

li = []
sum = 0

for filename in all_files:
    print(filename)
    df = pd.read_csv(filename) #on_bad_lines='skip')
    print(df.shape[0])
    sum += df.shape[0]
    if li:
        df = df.reindex(columns=li[0].columns)
    li.append(df)

print(sum)
tree_dataset = pd.concat(li, axis=0, ignore_index=True)
# Out:
# /content/drive/MyDrive/tree_dataset/Atlanta_Final_2022-06-18.csv
# 41307
# /content/drive/MyDrive/tree_dataset/AuroraCO_Final_2022-06-18.csv
# 57658
# /content/drive/MyDrive/tree_dataset/Arlington_Final_2022-06-18.csv
# 14827
# /content/drive/MyDrive/tree_dataset/Baltimore_Final_2022-06-18.csv
# 121296
# /content/drive/MyDrive/tree_dataset/Buffalo_Final_2022-06-18.csv
# 132995
# /content/drive/MyDrive/tree_dataset/Boston_Final_2022-06-18.csv
# 1333
# /content/drive/MyDrive/tree_dataset/Austin_Final_2022-06-18.csv
# 7295
# /content/drive/MyDrive/tree_dataset/CapeCoral_Final_2022-06-18.csv
# 34287
# /content/drive/MyDrive/tree_dataset/Denver_Final_2022-06-18.csv
# 284739
# /content/drive/MyDrive/tree_dataset/Dallas_Final_2022-06-18.csv
# 6218
# /content/drive/MyDrive/tree_dataset/Columbus_Final_2022-06-18.csv
# 151937
# /content/drive/MyDrive/tree_dataset/ColoradoSprings_Final_2022-06-18.csv
# 25478
# /content/drive/MyDrive/tree_dataset/DesMoines_Final_2022-06-18.csv
# 16875
# ...

# %%
tree_dataset.tail()
# Out:
#         city_ID most_recent_observation most_recent_observation_type  \
# 5660232     NaN                     NaN                          NaN
# 5660233     NaN                     NaN                          NaN
# 5660234     NaN                     NaN                          NaN
# 5660235     NaN                     NaN                          NaN
# 5660236     NaN                     NaN                          NaN
#
#         scientific_name city state  longitude_coordinate  latitude_coordinate  \
# 5660232             NaN  NaN   NaN                   NaN                  NaN
# 5660233             NaN  NaN   NaN                   NaN                  NaN
# 5660234             NaN  NaN   NaN                   NaN                  NaN
# 5660235             NaN  NaN   NaN                   NaN                  NaN
# 5660236             NaN  NaN   NaN                   NaN                  NaN
#
#         address native  ... location_name  ward district overhead_utility  \
# ...

# %%
quantitative_tree = tree_dataset[['']]
qualitative_tree = tree_dataset[['']]

# %%
print(tree_dataset.shape) # N=5132890, 28 columns expected
# Out:
# (5660237, 28)

# %%
tree_dataset['city'].value_counts().to_frame()
# Out:
#                city
# Los Angeles  720140
# New York     683788
# San Jose     347669
# Denver       284739
# Portland     218602
# ...             ...
# Muskego           2
# Heeia             1
# Lutz              1
# Aiea              1
# Wind Lake         1
#
# [145 rows x 1 columns]

# %%
for i in list(tree_dataset.columns.values):
  print(i)
  print(tree_dataset[i].value_counts())
  print("\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n")
# Out:
# city_ID
#                            172
# 10340-155-3001-0095-000    126
# 35778-290-3005-0057-000    125
# 2                           63
# 24875-000-3001-0000-000     48
#                           ...
# 516,260                      1
# 516,051                      1
# 513,945                      1
# 517,291                      1
# 20480-130-3005-0330-000      1
# Name: city_ID, Length: 2305323, dtype: int64
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# most_recent_observation
# 04/27/2019                127866
# 03/23/2015                 96072
# 01/08/2020                 56425
# 11/15/2017                 45342
# 04/11/2018                 29125
#                            ...
# 2022/05/24 19:40:10+00         1
# 2022/05/27 14:35:04+00         1
# 2022/05/25 17:49:57+00         1
# 2022/05/18 20:37:22+00         1
# 2022/03/04 20:23:34+00         1
# Name: most_recent_observation, Length: 18927, dtype: int64
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# ...
